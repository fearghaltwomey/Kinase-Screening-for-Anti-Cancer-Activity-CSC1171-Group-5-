# %%
# Pips
# !pip install pandas
# !pip install scikit-learn
# !pip install lightgbm
# !pip install xgboost
# !pip install catboost
# Out:
# Requirement already satisfied: pandas in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: lightgbm in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from lightgbm) (2.2.6)
# Requirement already satisfied: scipy in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from lightgbm) (1.16.0)
# Requirement already satisfied: xgboost in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from xgboost) (1.16.0)
# Requirement already satisfied: catboost in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (3.10.3)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (2.2.6)
# Requirement already satisfied: pandas>=0.24 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (2.3.0)
# Requirement already satisfied: scipy in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: plotly in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (6.4.0)
# Requirement already satisfied: six in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\fearg\anaconda3\envs\dcu\lib\site-packages (from plotly->catboost) (2.10.2)

# %%
# Function / Package Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMClassifier, LGBMRegressor
from xgboost import XGBClassifier, XGBRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC, SVR
from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.metrics import accuracy_score
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp
from sklearn.ensemble import VotingClassifier, VotingRegressor
import warnings; warnings.filterwarnings('ignore')

# %%
# Data Imports / Manipulation
df1 = pd.read_csv(r"Representative_kinases (1)\Representative_kinases\Rep_kinases_dataset.csv", sep= "	")
df2 = pd.read_csv(r"Dark Matter (I'm not running descriptors again).csv")

# Sort Kinases, Merge, etc.
# end with df_Kinase / df_KinaseGroup (~x20)

# %%
# Define Functions
def clean_df1(df1):
    df1 = df1[df1["p_standard_type"] == "pIC50"]
    df1["SMILES"] = df1["NonstereoAromaticSMILES"]
    df1["Value"] = df1["p_value"]
    df1["Class"] = 1
    df1["Kinase"] = df1["Kinase_name"]
    df1["Group"] = df1["Kinase_group"]    
    dfx = df1[["SMILES", "Class", "Value", "Kinase", "Group"]]
    del df1
    
    return dfx

def clean_df2(df2):
    df2["Value"] = 0
    df2["Kinase"] = "n/a"
    df2["Group"]= "n/a"
    dfy = df2[["SMILES", "Class", "Value", "Kinase", "Group"]]
    del df2
    
    return dfy
    
def validate_df(df):
    required_cols = {"SMILES", "Class", "Value", "Kinase", "Group", "Fingerprint"}
    if df.shape[0] <= 1000:
        raise ValueError(f"Not enough data: {df.shape[0]} elements")
    if set(df.columns) != required_cols:
        raise TypeError(f"Incorrect dataframe structure: \nProvided {list(df.columns)} \nExpected {list(required_cols)}")

def splits(df, mode= 1):
    if mode == 1:
        y = df["Class"]
    elif mode == 0:
        y = df["Value"]
    else:
        raise ValueError(f"{mode} is not a valid key. Use mode= 1 (clf) or mode= 0 (reg)")

    X = df["Fingerprint"]
    X_remainder, X_test, y_remainder, y_test = train_test_split(X, y, test_size= 0.2)
    X_train, X_val, y_train, y_val = train_test_split(X_remainder, y_remainder, test_size= 0.25)

    return X_train, X_test, X_val, y_train, y_test, y_val

def gen_fps(df, fingerprint_type="Morgan", resolution=1024):
    if "SMILES" not in df.columns:
        raise ValueError("DataFrame must contain a 'SMILES' column.")
    
    smiles = df["SMILES"].tolist()
    mols = [Chem.MolFromSmiles(s) for s in smiles if Chem.MolFromSmiles(s)]
    del smiles
    if fingerprint_type == 'Morgan':
        generator = rdFingerprintGenerator.GetMorganGenerator(radius=3, fpSize=resolution)
    elif fingerprint_type == 'AtomPair':
        generator = rdFingerprintGenerator.GetAtomPairGenerator(fpSize=resolution)
    else:
        raise ValueError(f"Unsupported fingerprint type: {fingerprint_type}")
    fingerprints = generator.GetFingerprints(mols)
    del mols

    return fingerprints
    del fingerprints

def hyper_params(clf, params, scoring, X, y):
    grid = GridSearchCV(clf, params, cv= 5, scoring= scoring)
    grid.fit(X, y)
    cv_results = grid.cv_results_
    all_scores = cv_results['mean_test_score']
    best_index = grid.best_index_
    fold_scores = [
        cv_results['split0_test_score'][best_index], cv_results['split1_test_score'][best_index], cv_results['split2_test_score'][best_index], cv_results['split3_test_score'][best_index], cv_results['split4_test_score'][best_index]
    ]
    
    return grid.best_params_, grid.best_score_, fold_scores
    del grid

def run_friedman_nemenyi(metric_matrix, metric_name):
    print(f"\nTesting: {metric_name}")
    stat, p = friedmanchisquare(*[metric_matrix[:, i] for i in range(metric_matrix.shape[1])])
    print(f"Friedman test statistic: {stat:.4f}, p-value: {p:.4f}")
    if p < 0.05:
        print(f"Significant differences found. \n\nNemenyi post-hoc test for {metric_name}:")
        df = pd.DataFrame(metric_matrix, columns=models)
        nemenyi = sp.posthoc_nemenyi_friedman(df)
        print(nemenyi)
    else:
        print("No significant differences found.")

def create_ensemble_model(models_dict):
    estimators = [(name, clf) for name, clf in models_dict.items()]
    ensemble_clf = VotingClassifier(
        estimators=estimators,
        voting="soft"
    )
    
    return ensemble_clf

# %%
# define lists, dicts, dataframes etc.

# Light Gradient Boosting (LGB)
clfLGB = LGBMClassifier(random_state = 42)
regLGB = LGBMRegressor(random_state = 42)
LGB_params = {
    "num_leaves": [10, 50, 100],
    "max_depth": [-1, 2, 5],
    "learning_rate": [0.01, 0.1, 0.2],
    "feature_fraction": [0.1, 0.5, 1]
}
# 3x3x3x3 training grid - 81 runs

# Extreme Gradient Boosting (XGB)
clfXGB = XGBClassifier(random_state = 42)
regXGB = XGBRegressor(random_state = 42)
XGB_params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [-1, 2, 5],
    "learning_rate": [0.01, 0.1, 0.2],
    "subsample": [0.1, 0.5, 1.0]
}
# 3x3x3x3 training grid - 81 runs

# Multilayer Perceptron (MLP)
clfMLP = MLPClassifier(random_state = 42)
regMLP = MLPRegressor(random_state = 42)
MLP_params = {
    "hidden_layer_sizes": [(100,), (10,10)],
    "learning_rate_init": [0.001, 0.002, 0.005],
    "alpha": [0.0001, 0.0002]
}
# 2x3x2 training grid - 12 runs

# Random Forest (RF)
clfRF = RandomForestClassifier(random_state = 42)
regRF = RandomForestRegressor(random_state = 42)
RF_params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [None, 2, 5],
    "max_features": [10, 100],
    "min_samples_split": [2, 5, 7]
}
# 3x3x3x3 training grid - 81 runs

# Support Vector Machine (SVM)
clfSVM = SVC()
regSVM = SVR()
SVM_params = {
    "C": [1, 0.5, 2, 5],
    "kernel": ["linear", "rbf"]
}
# 4x2 training grid - 8 runs

# CatBoost (CB)
clfCB = CatBoostClassifier(random_seed = 42)
regCB = CatBoostRegressor(random_seed = 42)
CB_params = {
    "iterations": [500],
    "depth": [2, 5, 7],
    "learning_rate": [0.01, 0.02, 0.03],
    "l2_leaf_reg": [1.0, 2.0, 3.0]
}
# 3x3x3x3 training grid - 81 runs

classifiers = {
    "LGB": LGBMClassifier(random_state= 42, **LGB_params),
    "XGB": XGBClassifier(random_state= 42, **XGB_params),
    "MLP": MLPClassifier(random_state= 42, **MLP_params),
    "RF": RandomForestClassifier(random_state= 42, **RF_params),
    "SVC": SVC(**SVM_params),
    "CB": CatBoostClassifier(random_seed= 42, **CB_params)
}

regressors = {
    "LGB": LGBMRegressor(random_state= 42, **LGB_params),
    "XGB": XGBRegressor(random_state= 42, **XGB_params),
    "MLP": MLPRegressor(random_state= 42, **MLP_params),
    "RF": RandomForestRegressor(random_state= 42, **RF_params),
    "SVC": SVR(**SVM_params),
    "CB": CatBoostRegressor(random_seed= 42, **CB_params)
}

models=  ["LGB", "XGB", "MLP", "RF", "SVM", "CatBoost"]

# %%
df_KDR = df1[df1["Kinase_name"] == "KDR"]
df_FLT1 = df1[df1["Kinase_name"] == "FLT1"]
df_p110a = df1[df1["Kinase_name"] == "p110a"]
df_JAK1 = df1[df1["Kinase_name"] == "JAK1"]
df_JAK2 = df1[df1["Kinase_name"] == "JAK2"]
df_ErbB2 = df1[df1["Kinase_name"] == "ErbB2"]
df_EGFR = df1[df1["Kinase_name"] == "EGFR"]
df_PIM1 = df1[df1["Kinase_name"] == "PIM1"]
df_ROCK1 = df1[df1["Kinase_name"] == "ROCK1"]
df_ABL1 = df1[df1["Kinase_name"] == "ABL1"]

df_TK = df1[df1["Kinase_group"] == "TK"]
df_CMGC = df1[df1["Kinase_group"] == "CMGC"]
df_AGC = df1[df1["Kinase_group"] == "AGC"]
df_CAMK = df1[df1["Kinase_group"] == "CAMK"]
df_Atypical = df1[df1["Kinase_group"] == "Atypical"]

kinase_dfs = [
    df_KDR,
    df_FLT1,
    df_p110a,
    df_JAK1,
    df_JAK2,
    df_ErbB2,
    df_EGFR,
    df_PIM1,
    df_ROCK1,
    df_ABL1,
    df_TK,
    df_CMGC,
    df_AGC,
    df_CAMK,
    df_Atypical
]
cleaned_kinase_dfs1 = [clean_df1(i) for i in kinase_dfs]
del kinase_dfs

df2 = clean_df2(df2)

cleaned_kinase_dfs2 = []
z = 1
for i in cleaned_kinase_dfs1:
    i["Fingerprint"] = gen_fps(i, "Morgan", 2048)
    cleaned_kinase_dfs2.append(i)
    print("Iteration ",z," Complete") # for my sanity, waste of computation
    z+=1
del cleaned_kinase_dfs1

# Necessary to stop jupyter from breaking (too much data per package -> break into smaller packages)
dfs = np.array_split(df2, 10)
cleaned_dfs = []
for i in dfs:
    i["Fingerprint"] = gen_fps(i, "Morgan", 2048)
    cleaned_dfs.append(i)
    print("Iteration ",z," Complete")
    z+=1
del dfs
df2 = pd.concat([i for i in cleaned_dfs], axis= 0)
del cleaned_dfs, z

for i in cleaned_kinase_dfs2:
    validate_df(i)
validate_df(df2)

dataframes = [pd.concat([i, df2], axis= 0, ignore_index= True) for i in cleaned_kinase_dfs2]
del df2, cleaned_kinase_dfs2

X= 1
df_KDR = dataframes[0] # Reassign to dataframe
X_train_KDR_class, X_test_KDR_class, X_val_KDR_class, y_train_KDR_class, y_test_KDR_class, y_val_KDR_class = splits(df_KDR, mode= 1) # Classification
X_train_KDR_reg, X_test_KDR_reg, X_val_KDR_reg, y_train_KDR_reg, y_test_KDR_reg, y_val_KDR_reg = splits(df_KDR, mode= 0) # Regression
print("Split ", X, " Complete")
X +=1
df_FLT1 = dataframes[1]
X_train_FLT1_class, X_test_FLT1_class, X_val_FLT1_class, y_train_FLT1_class, y_test_FLT1_class, y_val_FLT1_class = splits(df_KDR, mode= 1)
X_train_FLT1_reg, X_test_FLT1_reg, X_val_FLT1_reg, y_train_FLT1_reg, y_test_FLT1_reg, y_val_FLT1_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_p110a = dataframes[2]
X_train_p110a_class, X_test_p110a_class, X_val_p110a_class, y_train_p110a_class, y_test_p110a_class, y_val_p110a_class = splits(df_KDR, mode= 1)
X_train_p110a_reg, X_test_p110a_reg, X_val_p110a_reg, y_train_p110a_reg, y_test_p110a_reg, y_val_p110a_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_JAK1 = dataframes[3]
X_train_JAK1_class, X_test_JAK1_class, X_val_JAK1_class, y_train_JAK1_class, y_test_JAK1_class, y_val_JAK1_class = splits(df_KDR, mode= 1)
X_train_JAK1_reg, X_test_JAK1_reg, X_val_JAK1_reg, y_train_JAK1_reg, y_test_JAK1_reg, y_val_JAK1_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_JAK2 = dataframes[4]
X_train_JAK2_class, X_test_JAK2_class, X_val_JAK2_class, y_train_JAK2_class, y_test_JAK2_class, y_val_JAK2_class = splits(df_KDR, mode= 1)
X_train_JAK2_reg, X_test_JAK2_reg, X_val_JAK2_reg, y_train_JAK2_reg, y_test_JAK2_reg, y_val_JAK2_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_ErbB2 = dataframes[5]
X_train_ErbB2_class, X_test_ErbB2_class, X_val_ErbB2_class, y_train_ErbB2_class, y_test_ErbB2_class, y_val_ErbB2_class = splits(df_KDR, mode= 1)
X_train_ErbB2_reg, X_test_ErbB2_reg, X_val_ErbB2_reg, y_train_ErbB2_reg, y_test_ErbB2_reg, y_val_ErbB2_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_EGFR = dataframes[6]
X_train_EGFR_class, X_test_EGFR_class, X_val_EGFR_class, y_train_EGFR_class, y_test_EGFR_class, y_val_EGFR_class = splits(df_KDR, mode= 1)
X_train_EGFR_reg, X_test_EGFR_reg, X_val_EGFR_reg, y_train_EGFR_reg, y_test_EGFR_reg, y_val_EGFR_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_PIM1 = dataframes[7]
X_train_PIM1_class, X_test_PIM1_class, X_val_PIM1_class, y_train_PIM1_class, y_test_PIM1_class, y_val_PIM1_class = splits(df_KDR, mode= 1)
X_train_PIM1_reg, X_test_PIM1_reg, X_val_PIM1_reg, y_train_PIM1_reg, y_test_PIM1_reg, y_val_PIM1_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_ROCK1 = dataframes[8]
X_train_ROCK1_class, X_test_ROCK1_class, X_val_ROCK1_class, y_train_ROCK1_class, y_test_ROCK1_class, y_val_ROCK1_class = splits(df_KDR, mode= 1)
X_train_ROCK1_reg, X_test_ROCK1_reg, X_val_ROCK1_reg, y_train_ROCK1_reg, y_test_ROCK1_reg, y_val_ROCK1_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_ABL1 = dataframes[9]
X_train_ABL1_class, X_test_ABL1_class, X_val_ABL1_class, y_train_ABL1_class, y_test_ABL1_class, y_val_ABL1_class = splits(df_KDR, mode= 1)
X_train_ABL1_reg, X_test_ABL1_reg, X_val_ABL1_reg, y_train_ABL1_reg, y_test_ABL1_reg, y_val_ABL1_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_TK = dataframes[10]
X_train_TK_class, X_test_TK_class, X_val_TK_class, y_train_TK_class, y_test_TK_class, y_val_TK_class = splits(df_KDR, mode= 1)
X_train_TK_reg, X_test_TK_reg, X_val_TK_reg, y_train_TK_reg, y_test_TK_reg, y_val_TK_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_CMGC = dataframes[11]
X_train_CMGC_class, X_test_CMGC_class, X_val_CMGC_class, y_train_CMGC_class, y_test_CMGC_class, y_val_CMGC_class = splits(df_KDR, mode= 1)
X_train_CMGC_reg, X_test_CMGC_reg, X_val_CMGC_reg, y_train_CMGC_reg, y_test_CMGC_reg, y_val_CMGC_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_AGC = dataframes[12]
X_train_AGC_class, X_test_AGC_class, X_val_AGC_class, y_train_AGC_class, y_test_AGC_class, y_val_AGC_class = splits(df_KDR, mode= 1)
X_train_AGC_reg, X_test_AGC_reg, X_val_AGC_reg, y_train_AGC_reg, y_test_AGC_reg, y_val_AGC_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_CAMK = dataframes[13]
X_train_CAMK_class, X_test_CAMK_class, X_val_CAMK_class, y_train_CAMK_class, y_test_CAMK_class, y_val_CAMK_class = splits(df_KDR, mode= 1)
X_train_CAMK_reg, X_test_CAMK_reg, X_val_CAMK_reg, y_train_CAMK_reg, y_test_CAMK_reg, y_val_CAMK_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
X +=1
df_Atypical = dataframes[14]
X_train_Atypical_class, X_test_Atypical_class, X_val_Atypical_class, y_train_Atypical_class, y_test_Atypical_class, y_val_Atypical_class = splits(df_KDR, mode= 1)
X_train_Atypical_reg, X_test_Atypical_reg, X_val_Atypical_reg, y_train_Atypical_reg, y_test_Atypical_reg, y_val_Atypical_reg = splits(df_KDR, mode= 0)
print("Split ", X, " Complete")
del X
# Out:
# Iteration  1  Complete
# Iteration  2  Complete
# Iteration  3  Complete
# Iteration  4  Complete
# Iteration  5  Complete
# Iteration  6  Complete
# Iteration  7  Complete
# Iteration  8  Complete
# Iteration  9  Complete
# Iteration  10  Complete
# Iteration  11  Complete
# Iteration  12  Complete
# Iteration  13  Complete
# Iteration  14  Complete
# Iteration  15  Complete
# Iteration  16  Complete
# Iteration  17  Complete
# Iteration  18  Complete
# Iteration  19  Complete
# Iteration  20  Complete
# Iteration  21  Complete
# Iteration  22  Complete
# Iteration  23  Complete
# Iteration  24  Complete
# Iteration  25  Complete
# Split  1  Complete
# Split  2  Complete
# Split  3  Complete
# Split  4  Complete
# Split  5  Complete
# Split  6  Complete
# Split  7  Complete
# Split  8  Complete
# Split  9  Complete
# Split  10  Complete
# Split  11  Complete
# Split  12  Complete
# Split  13  Complete
# Split  14  Complete
# Split  15  Complete

# %%
# Testing for Speed

# RandomForestClassifier(n_jobs = -1) -> use all available cores. default is set to n_jobs = None -> one core (no parallel processing)
# Works for XGB, LGB and (conditionally) SVM. CatBoost uses thread_count = -1 instead. Not supported on MLP
# On this system (AI7 350 & 16gb ram), (should) increase speed by ~8x
# Note: do not run on battery for this, automatically parks 12/16 threads (uses 4 single-threaded cores) <- in the case of my laptop

clfRF = RandomForestClassifier(random_state = 42, n_jobs= -1)
regRF = RandomForestRegressor(random_state = 42, n_jobs= -1)
RF_params = {
    "n_estimators": [50, 100],
    "max_depth": [None],
    "max_features": [10],
    "min_samples_split": [2]
}
best_params, best_score, best_scores = hyper_params(clfSVM, SVM_params, "accuracy", np.stack(X_val_ABL1_class), y_val_ABL1_class,)
#^runs in ~55 mins (running 8 param combos in 2-fold, wtf??????)
#running for literally one change in parameters (50/100 estimators): start 19.29, end (cancelled) 20.29

# %% [markdown]
# *Do Not Run Cell Above*
#
#
# It takes about half a decade to run

# %%
# Setting up classifiers / regressors using default params (estimated ~2.5-12.5 year runtime for parameter tuning on this device, we would need a server)
"""
# Light Gradient Boosting (LGB)
clfLGB = LGBMClassifier(random_state = 42)
regLGB = LGBMRegressor(random_state = 42)

# Extreme Gradient Boosting (XGB)
clfXGB = XGBClassifier(random_state = 42)
regXGB = XGBRegressor(random_state = 42)

# Multilayer Perceptron (MLP)
clfMLP = MLPClassifier(random_state = 42)
regMLP = MLPRegressor(random_state = 42)

# Random Forest (RF)
clfRF = RandomForestClassifier(random_state = 42)
regRF = RandomForestRegressor(random_state = 42)

# Support Vector Machine (SVM)
clfSVM = SVC()
regSVM = SVR()

# CatBoost (CB)
clfCB = CatBoostClassifier(random_seed = 42)
regCB = CatBoostRegressor(random_seed = 42)
"""
classifiers = {
    "LGB": LGBMClassifier(random_state= 42),
    "XGB": XGBClassifier(random_state= 42, objective='binary:logistic'),
    "MLP": MLPClassifier(random_state= 42),
    "RF": RandomForestClassifier(random_state= 42),
    "SVC": SVC(probability= True),
    "CB": CatBoostClassifier(random_seed= 42, verbose= False)
}

regressors = {
    "LGB": LGBMRegressor(random_state= 42),
    "XGB": XGBRegressor(random_state= 42),
    "MLP": MLPRegressor(random_state= 42),
    "RF": RandomForestRegressor(random_state= 42),
    "SVC": SVR(),
    "CB": CatBoostRegressor(random_seed= 42)
}

models=  ["LGB", "XGB", "MLP", "RF", "SVM", "CatBoost"]

# %%
from sklearn.svm import LinearSVC
classifiers = {
    "LGB": LGBMClassifier(random_state= 42),
    "MLP": MLPClassifier(random_state= 42),
    "RF": RandomForestClassifier(random_state= 42),
    "SVC": LinearSVC(),
    "CB": CatBoostClassifier(random_seed= 42, verbose= False)
}

def create_ensemble_model(models_dict):
    estimators = [(name, clf) for name, clf in models_dict.items()]
    ensemble_clf = VotingClassifier(
        estimators=estimators,
        voting="soft"
    )
    return ensemble_clf

clf = create_ensemble_model(classifiers)

clf.fit(np.stack(X_train_EGFR_class), y_train_EGFR_class)
# 15 minute training time roughly? (didn't keep track)
# Out:
# [LightGBM] [Info] Number of positive: 3292, number of negative: 470427
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.715982 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4096
# [LightGBM] [Info] Number of data points in the train set: 473719, number of used features: 2048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.006949 -> initscore=-4.962146
# [LightGBM] [Info] Start training from score -4.962146
# VotingClassifier(estimators=[('LGB', LGBMClassifier(random_state=42)),
#                              ('MLP', MLPClassifier(random_state=42)),
#                              ('RF', RandomForestClassifier(random_state=42)),
#                              ('SVC', LinearSVC()),
#                              ('CB',
#                               <catboost.core.CatBoostClassifier object at 0x0000018CCAE3D810>)],
#                  voting='soft')

# %%
from sklearn.metrics import accuracy_score
y_pred_EGFR_class = clf.predict(np.stack(X_test_EGFR_class))
accuracy = accuracy_score(y_test_EGFR_class, y_pred_EGFR_class)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 y_pred_EGFR_class = clf.predict(np.stack(X_test_EGFR_class))
#       3 accuracy = accuracy_score(y_test_EGFR_class, y_pred_EGFR_class)
#       4 print("Accuracy:", accuracy)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:422, in VotingClassifier.predict(self, X)
#     420 check_is_fitted(self)
#     421 if self.voting == "soft":
# --> 422     maj = np.argmax(self.predict_proba(X), axis=1)
#     424 else:  # 'hard' voting
#     425     predictions = self._predict(X)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:463, in VotingClassifier.predict_proba(self, X)
#     449 """Compute probabilities of possible outcomes for samples in X.
#     450
#     451 Parameters
#    (...)    459     Weighted average probability for each class per sample.
#     460 """
#     461 check_is_fitted(self)
#     462 avg = np.average(
# --> 463     self._collect_probas(X), axis=0, weights=self._weights_not_none
#     464 )
#     465 return avg
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:438, in VotingClassifier._collect_probas(self, X)
#     436 def _collect_probas(self, X):
#     437     """Collect results from clf.predict calls."""
# --> 438     return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'

# %%
scores = clf.decision_function(X_test_EGFR_class)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 scores = clf.decision_function(X_test_EGFR_class)
#
# AttributeError: 'VotingClassifier' object has no attribute 'decision_function'

# %%
from sklearn.svm import LinearSVC
# 15 minute training time roughly? (didn't keep track)
# Calibrated classifier lets svc work with ensemble voting
from sklearn.calibration import CalibratedClassifierCV
svc_calibrated = CalibratedClassifierCV(SVC, method='sigmoid')
classifiers = {
    "LGB": LGBMClassifier(random_state= 42),
    "MLP": MLPClassifier(random_state= 42),
    "RF": RandomForestClassifier(random_state= 42),
    "SVC": svc_calibrated,
    "CB": CatBoostClassifier(random_seed= 42, verbose= False)
}

def create_ensemble_model(models_dict):
    estimators = [(name, clf) for name, clf in models_dict.items()]
    ensemble_clf = VotingClassifier(
        estimators=estimators,
        voting="soft"
    )
    return ensemble_clf

clf = create_ensemble_model(classifiers)

clf.fit(np.stack(X_train_EGFR_class), y_train_EGFR_class)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 23
#      19     return ensemble_clf
#      21 clf = create_ensemble_model(classifiers)
# ---> 23 clf.fit(np.stack(X_train_EGFR_class), y_train_EGFR_class)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:405, in VotingClassifier.fit(self, X, y, **fit_params)
#     402 self.classes_ = self.le_.classes_
#     403 transformed_y = self.le_.transform(y)
# --> 405 return super().fit(X, transformed_y, **fit_params)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:80, in _BaseVoting.fit(self, X, y, **fit_params)
#      77 @abstractmethod
#      78 def fit(self, X, y, **fit_params):
#      79     """Get common fit operations."""
# ---> 80     names, clfs = self._validate_estimators()
#      82     if self.weights is not None and len(self.weights) != len(self.estimators):
#      83         raise ValueError(
#      84             "Number of `estimators` and weights must be equal; got"
#      85             f" {len(self.weights)} weights, {len(self.estimators)} estimators"
#      86         )
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_base.py:236, in _BaseHeterogeneousEnsemble._validate_estimators(self)
#     233 is_estimator_type = is_classifier if is_classifier(self) else is_regressor
#     235 for est in estimators:
# --> 236     if est != "drop" and not is_estimator_type(est):
#     237         raise ValueError(
#     238             "The estimator {} should be a {}.".format(
#     239                 est.__class__.__name__, is_estimator_type.__name__[3:]
#     240             )
#     241         )
#     243 return names, estimators
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\base.py:1213, in is_classifier(estimator)
#    1206     warnings.warn(
#    1207         f"passing a class to {print(inspect.stack()[0][3])} is deprecated and "
#    1208         "will be removed in 1.8. Use an instance of the class instead.",
#    1209         FutureWarning,
#    1210     )
#    1211     return getattr(estimator, "_estimator_type", None) == "classifier"
# -> 1213 return get_tags(estimator).estimator_type == "classifier"
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\_tags.py:325, in get_tags(estimator)
#     299 """Get estimator tags.
#     300
#     301 :class:`~sklearn.BaseEstimator` provides the estimator tags machinery.
#    (...)    321     The estimator tags.
#     322 """
#     324 try:
# --> 325     tags = estimator.__sklearn_tags__()
#     326 except AttributeError as exc:
#     327     # TODO(1.8): turn the warning into an error
#     328     if "object has no attribute '__sklearn_tags__'" in str(exc):
#     329         # Fall back to the default tags if the estimator does not
#     330         # implement __sklearn_tags__.
#    (...)    335         # method in the base class. Typically happens when only inheriting
#     336         # from Mixins.
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\calibration.py:567, in CalibratedClassifierCV.__sklearn_tags__(self)
#     565 def __sklearn_tags__(self):
#     566     tags = super().__sklearn_tags__()
# --> 567     tags.input_tags.sparse = get_tags(self._get_estimator()).input_tags.sparse
#     568     return tags
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\_tags.py:325, in get_tags(estimator)
#     299 """Get estimator tags.
#     300
#     301 :class:`~sklearn.BaseEstimator` provides the estimator tags machinery.
#    (...)    321     The estimator tags.
#     322 """
#     324 try:
# --> 325     tags = estimator.__sklearn_tags__()
#     326 except AttributeError as exc:
#     327     # TODO(1.8): turn the warning into an error
#     328     if "object has no attribute '__sklearn_tags__'" in str(exc):
#     329         # Fall back to the default tags if the estimator does not
#     330         # implement __sklearn_tags__.
#    (...)    335         # method in the base class. Typically happens when only inheriting
#     336         # from Mixins.
#
# TypeError: BaseSVC.__sklearn_tags__() missing 1 required positional argument: 'self'

# %%
for i in classifiers:
    i.fit(np.stack(X_train_EGFR_class), y_train_EGFR_class)

for i in classifiers, clf:
    accuracy = i.score(np.stack(X_test_EGFR_class), y_test_EGFR_class)
    print(f"Accuracy: {accuracy:.4f}")

# %%
# Attempting to 
from scipy import sparse

ensemble = VotingClassifier(estimators=[
    ('SVC', SVC(probability=True)),
    ('RF', RandomForestClassifier(random_state= 42, n_jobs= -1)), 
    ('LGB', LGBMClassifier(random_state= 42, n_jobs= -1)),
    ('MLP', MLPClassifier(random_state= 42)),
    ('CB', CatBoostClassifier(random_seed= 42, verbose= False))
], voting='soft')

ensemble.fit(X_train_EGFR_class, y_train_EGFR_class)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'ExplicitBitVect'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 12
#       2 from scipy import sparse
#       4 ensemble = VotingClassifier(estimators=[
#       5     ('SVC', SVC(probability=True)),
#       6     ('RF', RandomForestClassifier(random_state= 42, n_jobs= -1)),
#    (...)      9     ('CB', CatBoostClassifier(random_seed= 42, verbose= False))
#      10 ], voting='soft')
# ---> 12 ensemble.fit(np.array(X_train_EGFR_class), y_train_EGFR_class)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:405, in VotingClassifier.fit(self, X, y, **fit_params)
#     402 self.classes_ = self.le_.classes_
#     403 transformed_y = self.le_.transform(y)
# --> 405 return super().fit(X, transformed_y, **fit_params)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:99, in _BaseVoting.fit(self, X, y, **fit_params)
#      94         if "sample_weight" in fit_params:
#      95             routed_params[name].fit["sample_weight"] = fit_params[
#      96                 "sample_weight"
#      97             ]
# ---> 99 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     100     delayed(_fit_single_estimator)(
#     101         clone(clf),
#     102         X,
#     103         y,
#     104         fit_params=routed_params[name]["fit"],
#     105         message_clsname="Voting",
#     106         message=self._log_message(name, idx + 1, len(clfs)),
#     107     )
#     108     for idx, (name, clf) in enumerate(zip(names, clfs))
#     109     if clf != "drop"
#     110 )
#     112 self.named_estimators_ = Bunch()
#     114 # Uses 'drop' as placeholder for dropped estimators
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_base.py:39, in _fit_single_estimator(estimator, X, y, fit_params, message_clsname, message)
#      37 else:
#      38     with _print_elapsed_time(message_clsname, message):
# ---> 39         estimator.fit(X, y, **fit_params)
#      40 return estimator
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\svm\_base.py:197, in BaseLibSVM.fit(self, X, y, sample_weight)
#     195     check_consistent_length(X, y)
#     196 else:
# --> 197     X, y = validate_data(
#     198         self,
#     199         X,
#     200         y,
#     201         dtype=np.float64,
#     202         order="C",
#     203         accept_sparse="csr",
#     204         accept_large_sparse=False,
#     205     )
#     207 y = self._validate_targets(y)
#     209 sample_weight = np.asarray(
#     210     [] if sample_weight is None else sample_weight, dtype=np.float64
#     211 )
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1051         array = xp.astype(array, dtype, copy=False)
#    1052     else:
# -> 1053         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1054 except ComplexWarning as complex_warning:
#    1055     raise ValueError(
#    1056         "Complex data not supported\n{}\n".format(array)
#    1057     ) from complex_warning
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\utils\_array_api.py:757, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     755     array = numpy.array(array, order=order, dtype=dtype)
#     756 else:
# --> 757     array = numpy.asarray(array, order=order, dtype=dtype)
#     759 # At this point array is a NumPy ndarray. We convert it to an array
#     760 # container that is consistent with the input's namespace.
#     761 return xp.asarray(array)
#
# ValueError: setting an array element with a sequence.

# %%
X_train_EGFR_class = np.stack(X_train_EGFR_class)
X_train_EGFR_class.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 X_train_EGFR_class = np.stack(X_train_EGFR_class)
# ----> 2 X_train_EGFR_class.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
np.savetxt("test.csv", X_train_EGFR_class, delimiter=",", fmt="%d")

# %%
# Printing to dataframe -> will convert each train/test set to a dataframe with stacked molecular fingerprints, then print them to a .csv file called "variable name".csv

# Put them in a dictionary with their names as keys
dataframes = {
    'df1': df1,
    'df2': df2
}

# Save each to CSV using its name
for name, df in dataframes.items():
    df = np.stack(df)
    df.to_csv(f"{name}.csv", index=False)

# %%
printing_dict = {
    "X_train_KDR_class": X_train_KDR_class, 
    "X_test_KDR_class": X_test_KDR_class, 
    "X_val_KDR_class": X_val_KDR_class,
    "X_train_KDR_reg": X_train_KDR_reg, 
    "X_test_KDR_reg": X_test_KDR_reg, 
    "X_val_KDR_reg": X_val_KDR_reg, 
    "X_train_FLT1_class": X_train_FLT1_class, 
    "X_test_FLT1_class": X_test_FLT1_class, 
    "X_val_FLT1_class": X_val_FLT1_class, 
    "X_train_FLT1_reg": X_train_FLT1_reg, 
    "X_test_FLT1_reg": X_test_FLT1_reg, 
    "X_val_FLT1_reg": X_val_FLT1_reg, 
    "X_train_p110a_class": X_train_p110a_class, 
    "X_test_p110a_class": X_test_p110a_class, 
    "X_val_p110a_class": X_val_p110a_class, 
    "X_train_p110a_reg": X_train_p110a_reg, 
    "X_test_p110a_reg": X_test_p110a_reg, 
    "X_val_p110a_reg": X_val_p110a_reg, 
    "X_train_JAK1_class": X_train_JAK1_class, 
    "X_test_JAK1_class": X_test_JAK1_class, 
    "X_val_JAK1_class": X_val_JAK1_class, 
    "X_train_JAK1_reg": X_train_JAK1_reg, 
    "X_test_JAK1_reg": X_test_JAK1_reg, 
    "X_val_JAK1_reg": X_val_JAK1_reg, 
    "X_train_JAK2_class": X_train_JAK2_class, 
    "X_test_JAK2_class": X_test_JAK2_class, 
    "X_val_JAK2_class": X_val_JAK2_class, 
    "X_train_JAK2_reg": X_train_JAK2_reg, 
    "X_test_JAK2_reg": X_test_JAK2_reg, 
    "X_val_JAK2_reg": X_val_JAK2_reg, 
    "X_train_ErbB2_class": X_train_ErbB2_class, 
    "X_test_ErbB2_class": X_test_ErbB2_class, 
    "X_val_ErbB2_class": X_val_ErbB2_class, 
    "X_train_ErbB2_reg": X_train_ErbB2_reg, 
    "X_test_ErbB2_reg": X_test_ErbB2_reg, 
    "X_val_ErbB2_reg": X_val_ErbB2_reg, 
    "X_train_EGFR_class": X_train_EGFR_class, 
    "X_test_EGFR_class": X_test_EGFR_class, 
    "X_val_EGFR_class": X_val_EGFR_class, 
    "X_train_EGFR_reg": X_train_EGFR_reg, 
    "X_test_EGFR_reg": X_test_EGFR_reg, 
    "X_val_EGFR_reg": X_val_EGFR_reg, 
    "X_train_PIM1_class": X_train_PIM1_class, 
    "X_test_PIM1_class": X_test_PIM1_class, 
    "X_val_PIM1_class": X_val_PIM1_class, 
    "X_train_PIM1_reg": X_train_PIM1_reg, 
    "X_test_PIM1_reg": X_test_PIM1_reg, 
    "X_val_PIM1_reg": X_val_PIM1_reg, 
    "X_train_ROCK1_class": X_train_ROCK1_class, 
    "X_test_ROCK1_class": X_test_ROCK1_class, 
    "X_val_ROCK1_class": X_val_ROCK1_class, 
    "X_train_ROCK1_reg": X_train_ROCK1_reg, 
    "X_test_ROCK1_reg": X_test_ROCK1_reg, 
    "X_val_ROCK1_reg": X_val_ROCK1_reg, 
    "X_train_ABL1_class": X_train_ABL1_class, 
    "X_test_ABL1_class": X_test_ABL1_class, 
    "X_val_ABL1_class": X_val_ABL1_class, 
    "X_train_ABL1_reg": X_train_ABL1_reg, 
    "X_test_ABL1_reg": X_test_ABL1_reg, 
    "X_val_ABL1_reg": X_val_ABL1_reg, 
    "X_train_TK_class": X_train_TK_class, 
    "X_test_TK_class": X_test_TK_class, 
    "X_val_TK_class": X_val_TK_class, 
    "X_train_TK_reg": X_train_TK_reg, 
    "X_test_TK_reg": X_test_TK_reg, 
    "X_val_TK_reg": X_val_TK_reg, 
    "X_train_CMGC_class": X_train_CMGC_class, 
    "X_test_CMGC_class": X_test_CMGC_class, 
    "X_val_CMGC_class": X_val_CMGC_class, 
    "X_train_CMGC_reg": X_train_CMGC_reg, 
    "X_test_CMGC_reg": X_test_CMGC_reg, 
    "X_val_CMGC_reg": X_val_CMGC_reg, 
    "X_train_AGC_class": X_train_AGC_class, 
    "X_test_AGC_class": X_test_AGC_class, 
    "X_val_AGC_class": X_val_AGC_class, 
    "X_train_AGC_reg": X_train_AGC_reg, 
    "X_test_AGC_reg": X_test_AGC_reg, 
    "X_val_AGC_reg": X_val_AGC_reg, 
    "X_train_CAMK_class": X_train_CAMK_class, 
    "X_test_CAMK_class": X_test_CAMK_class, 
    "X_val_CAMK_class": X_val_CAMK_class, 
    "X_train_CAMK_reg": X_train_CAMK_reg, 
    "X_test_CAMK_reg": X_test_CAMK_reg, 
    "X_val_CAMK_reg": X_val_CAMK_reg, 
    "X_train_Atypical_class": X_train_Atypical_class, 
    "X_test_Atypical_class": X_test_Atypical_class, 
    "X_val_Atypical_class": X_val_Atypical_class, 
    "X_train_Atypical_reg": X_train_Atypical_reg, 
    "X_test_Atypical_reg": X_test_Atypical_reg, 
    "X_val_Atypical_reg": X_val_Atypical_reg
}

# %%
for name, df in printing_dict.items():
    arr = np.stack(df)
    del df
    print(f"{name} converted to np.arr")
    np.savetxt(f"{name}.csv", arr, delimiter=",", fmt="%d")
    del arr
    print(f"{name} printed to .csv file")

print("end")
# Out:
# X_train_KDR_class converted to np.arr
# X_train_KDR_class printed to .csv file
# X_test_KDR_class converted to np.arr
# X_test_KDR_class printed to .csv file
# X_val_KDR_class converted to np.arr
# X_val_KDR_class printed to .csv file
# X_train_KDR_reg converted to np.arr
# X_train_KDR_reg printed to .csv file
# X_test_KDR_reg converted to np.arr
# X_test_KDR_reg printed to .csv file
# X_val_KDR_reg converted to np.arr
# X_val_KDR_reg printed to .csv file
# X_train_FLT1_class converted to np.arr
# X_train_FLT1_class printed to .csv file
# X_test_FLT1_class converted to np.arr
# X_test_FLT1_class printed to .csv file
# X_val_FLT1_class converted to np.arr
# X_val_FLT1_class printed to .csv file
# X_train_FLT1_reg converted to np.arr
# X_train_FLT1_reg printed to .csv file
# X_test_FLT1_reg converted to np.arr
# X_test_FLT1_reg printed to .csv file
# X_val_FLT1_reg converted to np.arr
# X_val_FLT1_reg printed to .csv file
# X_train_p110a_class converted to np.arr
# X_train_p110a_class printed to .csv file
# X_test_p110a_class converted to np.arr
# X_test_p110a_class printed to .csv file
# X_val_p110a_class converted to np.arr
# X_val_p110a_class printed to .csv file
# X_train_p110a_reg converted to np.arr
# X_train_p110a_reg printed to .csv file
# X_test_p110a_reg converted to np.arr
# X_test_p110a_reg printed to .csv file
# X_val_p110a_reg converted to np.arr
# X_val_p110a_reg printed to .csv file
# X_train_JAK1_class converted to np.arr
# X_train_JAK1_class printed to .csv file
# X_test_JAK1_class converted to np.arr
# X_test_JAK1_class printed to .csv file
# X_val_JAK1_class converted to np.arr
# X_val_JAK1_class printed to .csv file
# X_train_JAK1_reg converted to np.arr
# X_train_JAK1_reg printed to .csv file
# X_test_JAK1_reg converted to np.arr
# X_test_JAK1_reg printed to .csv file
# X_val_JAK1_reg converted to np.arr
# X_val_JAK1_reg printed to .csv file
# X_train_JAK2_class converted to np.arr
# X_train_JAK2_class printed to .csv file
# X_test_JAK2_class converted to np.arr
# X_test_JAK2_class printed to .csv file
# X_val_JAK2_class converted to np.arr
# X_val_JAK2_class printed to .csv file
# X_train_JAK2_reg converted to np.arr
# X_train_JAK2_reg printed to .csv file
# X_test_JAK2_reg converted to np.arr
# X_test_JAK2_reg printed to .csv file
# X_val_JAK2_reg converted to np.arr
# X_val_JAK2_reg printed to .csv file
# X_train_ErbB2_class converted to np.arr
# X_train_ErbB2_class printed to .csv file
# X_test_ErbB2_class converted to np.arr
# X_test_ErbB2_class printed to .csv file
# X_val_ErbB2_class converted to np.arr
# X_val_ErbB2_class printed to .csv file
# X_train_ErbB2_reg converted to np.arr
# X_train_ErbB2_reg printed to .csv file
# X_test_ErbB2_reg converted to np.arr
# X_test_ErbB2_reg printed to .csv file
# X_val_ErbB2_reg converted to np.arr
# X_val_ErbB2_reg printed to .csv file
# X_train_EGFR_class converted to np.arr
# X_train_EGFR_class printed to .csv file
# X_test_EGFR_class converted to np.arr
# X_test_EGFR_class printed to .csv file
# X_val_EGFR_class converted to np.arr
# X_val_EGFR_class printed to .csv file
# X_train_EGFR_reg converted to np.arr
# X_train_EGFR_reg printed to .csv file
# X_test_EGFR_reg converted to np.arr
# X_test_EGFR_reg printed to .csv file
# X_val_EGFR_reg converted to np.arr
# X_val_EGFR_reg printed to .csv file
# X_train_PIM1_class converted to np.arr
# X_train_PIM1_class printed to .csv file
# X_test_PIM1_class converted to np.arr
# X_test_PIM1_class printed to .csv file
# X_val_PIM1_class converted to np.arr
# X_val_PIM1_class printed to .csv file
# X_train_PIM1_reg converted to np.arr
# X_train_PIM1_reg printed to .csv file
# X_test_PIM1_reg converted to np.arr
# X_test_PIM1_reg printed to .csv file
# X_val_PIM1_reg converted to np.arr
# X_val_PIM1_reg printed to .csv file
# X_train_ROCK1_class converted to np.arr
# X_train_ROCK1_class printed to .csv file
# X_test_ROCK1_class converted to np.arr
# X_test_ROCK1_class printed to .csv file
# X_val_ROCK1_class converted to np.arr
# X_val_ROCK1_class printed to .csv file
# X_train_ROCK1_reg converted to np.arr
# X_train_ROCK1_reg printed to .csv file
# X_test_ROCK1_reg converted to np.arr
# X_test_ROCK1_reg printed to .csv file
# X_val_ROCK1_reg converted to np.arr
# X_val_ROCK1_reg printed to .csv file
# X_train_ABL1_class converted to np.arr
# X_train_ABL1_class printed to .csv file
# X_test_ABL1_class converted to np.arr
# X_test_ABL1_class printed to .csv file
# X_val_ABL1_class converted to np.arr
# X_val_ABL1_class printed to .csv file
# X_train_ABL1_reg converted to np.arr
# X_train_ABL1_reg printed to .csv file
# X_test_ABL1_reg converted to np.arr
# X_test_ABL1_reg printed to .csv file
# X_val_ABL1_reg converted to np.arr
# X_val_ABL1_reg printed to .csv file
# X_train_TK_class converted to np.arr
# X_train_TK_class printed to .csv file
# X_test_TK_class converted to np.arr
# X_test_TK_class printed to .csv file
# X_val_TK_class converted to np.arr
# X_val_TK_class printed to .csv file
# X_train_TK_reg converted to np.arr
# X_train_TK_reg printed to .csv file
# X_test_TK_reg converted to np.arr
# X_test_TK_reg printed to .csv file
# X_val_TK_reg converted to np.arr
# X_val_TK_reg printed to .csv file
# X_train_CMGC_class converted to np.arr
# X_train_CMGC_class printed to .csv file
# X_test_CMGC_class converted to np.arr
# X_test_CMGC_class printed to .csv file
# X_val_CMGC_class converted to np.arr
# X_val_CMGC_class printed to .csv file
# X_train_CMGC_reg converted to np.arr
# X_train_CMGC_reg printed to .csv file
# X_test_CMGC_reg converted to np.arr
# X_test_CMGC_reg printed to .csv file
# X_val_CMGC_reg converted to np.arr
# X_val_CMGC_reg printed to .csv file
# X_train_AGC_class converted to np.arr
# X_train_AGC_class printed to .csv file
# X_test_AGC_class converted to np.arr
# X_test_AGC_class printed to .csv file
# X_val_AGC_class converted to np.arr
# X_val_AGC_class printed to .csv file
# X_train_AGC_reg converted to np.arr
# X_train_AGC_reg printed to .csv file
# X_test_AGC_reg converted to np.arr
# X_test_AGC_reg printed to .csv file
# X_val_AGC_reg converted to np.arr
# X_val_AGC_reg printed to .csv file
# X_train_CAMK_class converted to np.arr
# X_train_CAMK_class printed to .csv file
# X_test_CAMK_class converted to np.arr
# X_test_CAMK_class printed to .csv file
# X_val_CAMK_class converted to np.arr
# X_val_CAMK_class printed to .csv file
# X_train_CAMK_reg converted to np.arr
# X_train_CAMK_reg printed to .csv file
# X_test_CAMK_reg converted to np.arr
# X_test_CAMK_reg printed to .csv file
# X_val_CAMK_reg converted to np.arr
# X_val_CAMK_reg printed to .csv file
# X_train_Atypical_class converted to np.arr
# X_train_Atypical_class printed to .csv file
# X_test_Atypical_class converted to np.arr
# X_test_Atypical_class printed to .csv file
# X_val_Atypical_class converted to np.arr
# X_val_Atypical_class printed to .csv file
# X_train_Atypical_reg converted to np.arr
# X_train_Atypical_reg printed to .csv file
# X_test_Atypical_reg converted to np.arr
# X_test_Atypical_reg printed to .csv file
# X_val_Atypical_reg converted to np.arr
# X_val_Atypical_reg printed to .csv file
# end

# %%
printing_dict_y = {
    "y_train_KDR_class": y_train_KDR_class, 
    "y_test_KDR_class": y_test_KDR_class, 
    "y_val_KDR_class": y_val_KDR_class,
    "y_train_KDR_reg": y_train_KDR_reg, 
    "y_test_KDR_reg": y_test_KDR_reg, 
    "y_val_KDR_reg": y_val_KDR_reg, 
    "y_train_FLT1_class": y_train_FLT1_class, 
    "y_test_FLT1_class": y_test_FLT1_class, 
    "y_val_FLT1_class": y_val_FLT1_class, 
    "y_train_FLT1_reg": y_train_FLT1_reg, 
    "y_test_FLT1_reg": y_test_FLT1_reg, 
    "y_val_FLT1_reg": y_val_FLT1_reg, 
    "y_train_p110a_class": y_train_p110a_class, 
    "y_test_p110a_class": y_test_p110a_class, 
    "y_val_p110a_class": y_val_p110a_class, 
    "y_train_p110a_reg": y_train_p110a_reg, 
    "y_test_p110a_reg": y_test_p110a_reg, 
    "y_val_p110a_reg": y_val_p110a_reg, 
    "y_train_JAK1_class": y_train_JAK1_class, 
    "y_test_JAK1_class": y_test_JAK1_class, 
    "y_val_JAK1_class": y_val_JAK1_class, 
    "y_train_JAK1_reg": y_train_JAK1_reg, 
    "y_test_JAK1_reg": y_test_JAK1_reg, 
    "y_val_JAK1_reg": y_val_JAK1_reg, 
    "y_train_JAK2_class": y_train_JAK2_class, 
    "y_test_JAK2_class": y_test_JAK2_class, 
    "y_val_JAK2_class": y_val_JAK2_class, 
    "y_train_JAK2_reg": y_train_JAK2_reg, 
    "y_test_JAK2_reg": y_test_JAK2_reg, 
    "y_val_JAK2_reg": y_val_JAK2_reg, 
    "y_train_ErbB2_class": y_train_ErbB2_class, 
    "y_test_ErbB2_class": y_test_ErbB2_class, 
    "y_val_ErbB2_class": y_val_ErbB2_class, 
    "y_train_ErbB2_reg": y_train_ErbB2_reg, 
    "y_test_ErbB2_reg": y_test_ErbB2_reg, 
    "y_val_ErbB2_reg": y_val_ErbB2_reg, 
    "y_train_EGFR_class": y_train_EGFR_class, 
    "y_test_EGFR_class": y_test_EGFR_class, 
    "y_val_EGFR_class": y_val_EGFR_class, 
    "y_train_EGFR_reg": y_train_EGFR_reg, 
    "y_test_EGFR_reg": y_test_EGFR_reg, 
    "y_val_EGFR_reg": y_val_EGFR_reg, 
    "y_train_PIM1_class": y_train_PIM1_class, 
    "y_test_PIM1_class": y_test_PIM1_class, 
    "y_val_PIM1_class": y_val_PIM1_class, 
    "y_train_PIM1_reg": y_train_PIM1_reg, 
    "y_test_PIM1_reg": y_test_PIM1_reg, 
    "y_val_PIM1_reg": y_val_PIM1_reg, 
    "y_train_ROCK1_class": y_train_ROCK1_class, 
    "y_test_ROCK1_class": y_test_ROCK1_class, 
    "y_val_ROCK1_class": y_val_ROCK1_class, 
    "y_train_ROCK1_reg": y_train_ROCK1_reg, 
    "y_test_ROCK1_reg": y_test_ROCK1_reg, 
    "y_val_ROCK1_reg": y_val_ROCK1_reg, 
    "y_train_ABL1_class": y_train_ABL1_class, 
    "y_test_ABL1_class": y_test_ABL1_class, 
    "y_val_ABL1_class": y_val_ABL1_class, 
    "y_train_ABL1_reg": y_train_ABL1_reg, 
    "y_test_ABL1_reg": y_test_ABL1_reg, 
    "y_val_ABL1_reg": y_val_ABL1_reg, 
    "y_train_TK_class": y_train_TK_class, 
    "y_test_TK_class": y_test_TK_class, 
    "y_val_TK_class": y_val_TK_class, 
    "y_train_TK_reg": y_train_TK_reg, 
    "y_test_TK_reg": y_test_TK_reg, 
    "y_val_TK_reg": y_val_TK_reg, 
    "y_train_CMGC_class": y_train_CMGC_class, 
    "y_test_CMGC_class": y_test_CMGC_class, 
    "y_val_CMGC_class": y_val_CMGC_class, 
    "y_train_CMGC_reg": y_train_CMGC_reg, 
    "y_test_CMGC_reg": y_test_CMGC_reg, 
    "y_val_CMGC_reg": y_val_CMGC_reg, 
    "y_train_AGC_class": y_train_AGC_class, 
    "y_test_AGC_class": y_test_AGC_class, 
    "y_val_AGC_class": y_val_AGC_class, 
    "y_train_AGC_reg": y_train_AGC_reg, 
    "y_test_AGC_reg": y_test_AGC_reg, 
    "y_val_AGC_reg": y_val_AGC_reg, 
    "y_train_CAMK_class": y_train_CAMK_class, 
    "y_test_CAMK_class": y_test_CAMK_class, 
    "y_val_CAMK_class": y_val_CAMK_class, 
    "y_train_CAMK_reg": y_train_CAMK_reg, 
    "y_test_CAMK_reg": y_test_CAMK_reg, 
    "y_val_CAMK_reg": y_val_CAMK_reg, 
    "y_train_Atypical_class": y_train_Atypical_class, 
    "y_test_Atypical_class": y_test_Atypical_class, 
    "y_val_Atypical_class": y_val_Atypical_class, 
    "y_train_Atypical_reg": y_train_Atypical_reg, 
    "y_test_Atypical_reg": y_test_Atypical_reg, 
    "y_val_Atypical_reg": y_val_Atypical_reg
}

# %%
for name, df in printing_dict_y.items():
    df.to_csv(f"{name}.csv")
    del df
    print(f"{name} printed to .csv file")

print("end")
# Out:
# y_train_KDR_class printed to .csv file
# y_test_KDR_class printed to .csv file
# y_val_KDR_class printed to .csv file
# y_train_KDR_reg printed to .csv file
# y_test_KDR_reg printed to .csv file
# y_val_KDR_reg printed to .csv file
# y_train_FLT1_class printed to .csv file
# y_test_FLT1_class printed to .csv file
# y_val_FLT1_class printed to .csv file
# y_train_FLT1_reg printed to .csv file
# y_test_FLT1_reg printed to .csv file
# y_val_FLT1_reg printed to .csv file
# y_train_p110a_class printed to .csv file
# y_test_p110a_class printed to .csv file
# y_val_p110a_class printed to .csv file
# y_train_p110a_reg printed to .csv file
# y_test_p110a_reg printed to .csv file
# y_val_p110a_reg printed to .csv file
# y_train_JAK1_class printed to .csv file
# y_test_JAK1_class printed to .csv file
# y_val_JAK1_class printed to .csv file
# y_train_JAK1_reg printed to .csv file
# y_test_JAK1_reg printed to .csv file
# y_val_JAK1_reg printed to .csv file
# y_train_JAK2_class printed to .csv file
# y_test_JAK2_class printed to .csv file
# y_val_JAK2_class printed to .csv file
# y_train_JAK2_reg printed to .csv file
# y_test_JAK2_reg printed to .csv file
# y_val_JAK2_reg printed to .csv file
# y_train_ErbB2_class printed to .csv file
# y_test_ErbB2_class printed to .csv file
# y_val_ErbB2_class printed to .csv file
# y_train_ErbB2_reg printed to .csv file
# y_test_ErbB2_reg printed to .csv file
# y_val_ErbB2_reg printed to .csv file
# y_train_EGFR_class printed to .csv file
# y_test_EGFR_class printed to .csv file
# y_val_EGFR_class printed to .csv file
# y_train_EGFR_reg printed to .csv file
# y_test_EGFR_reg printed to .csv file
# y_val_EGFR_reg printed to .csv file
# y_train_PIM1_class printed to .csv file
# y_test_PIM1_class printed to .csv file
# y_val_PIM1_class printed to .csv file
# y_train_PIM1_reg printed to .csv file
# y_test_PIM1_reg printed to .csv file
# y_val_PIM1_reg printed to .csv file
# y_train_ROCK1_class printed to .csv file
# y_test_ROCK1_class printed to .csv file
# y_val_ROCK1_class printed to .csv file
# y_train_ROCK1_reg printed to .csv file
# y_test_ROCK1_reg printed to .csv file
# y_val_ROCK1_reg printed to .csv file
# y_train_ABL1_class printed to .csv file
# y_test_ABL1_class printed to .csv file
# y_val_ABL1_class printed to .csv file
# y_train_ABL1_reg printed to .csv file
# y_test_ABL1_reg printed to .csv file
# y_val_ABL1_reg printed to .csv file
# y_train_TK_class printed to .csv file
# y_test_TK_class printed to .csv file
# y_val_TK_class printed to .csv file
# y_train_TK_reg printed to .csv file
# y_test_TK_reg printed to .csv file
# y_val_TK_reg printed to .csv file
# y_train_CMGC_class printed to .csv file
# y_test_CMGC_class printed to .csv file
# y_val_CMGC_class printed to .csv file
# y_train_CMGC_reg printed to .csv file
# y_test_CMGC_reg printed to .csv file
# y_val_CMGC_reg printed to .csv file
# y_train_AGC_class printed to .csv file
# y_test_AGC_class printed to .csv file
# y_val_AGC_class printed to .csv file
# y_train_AGC_reg printed to .csv file
# y_test_AGC_reg printed to .csv file
# y_val_AGC_reg printed to .csv file
# y_train_CAMK_class printed to .csv file
# y_test_CAMK_class printed to .csv file
# y_val_CAMK_class printed to .csv file
# y_train_CAMK_reg printed to .csv file
# y_test_CAMK_reg printed to .csv file
# y_val_CAMK_reg printed to .csv file
# y_train_Atypical_class printed to .csv file
# y_test_Atypical_class printed to .csv file
# y_val_Atypical_class printed to .csv file
# y_train_Atypical_reg printed to .csv file
# y_test_Atypical_reg printed to .csv file
# y_val_Atypical_reg printed to .csv file
# end
