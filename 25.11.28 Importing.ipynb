# %%
import pandas as pd
import joblib

# %%
# All names of .csv files generated
printing_list = [
    "X_train_KDR_class", 
    "X_test_KDR_class",
    "X_val_KDR_class",
    "X_train_KDR_reg",
    "X_test_KDR_reg",
    "X_val_KDR_reg",
    "X_train_FLT1_class",
    "X_test_FLT1_class",
    "X_val_FLT1_class",
    "X_train_FLT1_reg",
    "X_test_FLT1_reg",
    "X_val_FLT1_reg",
    "X_train_p110a_class",
    "X_test_p110a_class",
    "X_val_p110a_class",
    "X_train_p110a_reg",
    "X_test_p110a_reg",
    "X_val_p110a_reg",
    "X_train_JAK1_class",
    "X_test_JAK1_class",
    "X_val_JAK1_class",
    "X_train_JAK1_reg",
    "X_test_JAK1_reg",
    "X_val_JAK1_reg",
    "X_train_JAK2_class",
    "X_test_JAK2_class",
    "X_val_JAK2_class",
    "X_train_JAK2_reg",
    "X_test_JAK2_reg",
    "X_val_JAK2_reg",
    "X_train_ErbB2_class",
    "X_test_ErbB2_class",
    "X_val_ErbB2_class",
    "X_train_ErbB2_reg",
    "X_test_ErbB2_reg",
    "X_val_ErbB2_reg",
    "X_train_EGFR_class",
    "X_test_EGFR_class",
    "X_val_EGFR_class",
    "X_train_EGFR_reg", 
    "X_test_EGFR_reg", 
    "X_val_EGFR_reg", 
    "X_train_PIM1_class", 
    "X_test_PIM1_class", 
    "X_val_PIM1_class", 
    "X_train_PIM1_reg", 
    "X_test_PIM1_reg", 
    "X_val_PIM1_reg", 
    "X_train_ROCK1_class", 
    "X_test_ROCK1_class", 
    "X_val_ROCK1_class", 
    "X_train_ROCK1_reg", 
    "X_test_ROCK1_reg", 
    "X_val_ROCK1_reg", 
    "X_train_ABL1_class", 
    "X_test_ABL1_class", 
    "X_val_ABL1_class", 
    "X_train_ABL1_reg", 
    "X_test_ABL1_reg", 
    "X_val_ABL1_reg", 
    "X_train_TK_class", 
    "X_test_TK_class", 
    "X_val_TK_class", 
    "X_train_TK_reg", 
    "X_test_TK_reg", 
    "X_val_TK_reg", 
    "X_train_CMGC_class", 
    "X_test_CMGC_class", 
    "X_val_CMGC_class", 
    "X_train_CMGC_reg", 
    "X_test_CMGC_reg", 
    "X_val_CMGC_reg", 
    "X_train_AGC_class", 
    "X_test_AGC_class", 
    "X_val_AGC_class", 
    "X_train_AGC_reg", 
    "X_test_AGC_reg", 
    "X_val_AGC_reg", 
    "X_train_CAMK_class", 
    "X_test_CAMK_class", 
    "X_val_CAMK_class", 
    "X_train_CAMK_reg", 
    "X_test_CAMK_reg", 
    "X_val_CAMK_reg", 
    "X_train_Atypical_class", 
    "X_test_Atypical_class", 
    "X_val_Atypical_class", 
    "X_train_Atypical_reg", 
    "X_test_Atypical_reg", 
    "X_val_Atypical_reg"
    ]

# %%
printing_list = [
    "X_train_KDR_class", 
    "X_train_KDR_reg",
    "X_train_FLT1_class",
    "X_train_FLT1_reg",
    "X_train_p110a_class",
    "X_train_p110a_reg",
    "X_train_JAK1_class",
    "X_train_JAK1_reg",
    "X_train_JAK2_class",
    "X_train_JAK2_reg",
    "X_train_ErbB2_class",
    "X_train_ErbB2_reg",
    "X_train_EGFR_class",
    "X_train_EGFR_reg", 
    "X_train_PIM1_class", 
    "X_train_PIM1_reg", 
    "X_train_ROCK1_class", 
    "X_train_ROCK1_reg", 
    "X_train_ABL1_class", 
    "X_train_ABL1_reg", 
    "X_train_TK_class", 
    "X_train_TK_reg", 
    "X_train_CMGC_class", 
    "X_train_CMGC_reg", 
    "X_train_AGC_class", 
    "X_train_AGC_reg", 
    "X_train_CAMK_class", 
    "X_train_CAMK_reg", 
    "X_train_Atypical_class", 
    "X_train_Atypical_reg"
    ]

# %%
# Only for classifiers for now
# Still need to export y-datasets (should be easier considering lack of 2048-bit bitvector)

for i in printing_list:
    X_train = pd.read_csv(f"{i}.csv")
    y_string = "y" + i[1:]
    y_train = pd.read_csv(f"{y_string}.csv")
    print(f"Data Imported \n({i})")
    
    ensemble = VotingClassifier(estimators=[
        ('SVC', SVC(probability=True)),
        ('RF', RandomForestClassifier(random_state= 42, n_jobs= -1)), 
        ('LGB', LGBMClassifier(random_state= 42, n_jobs= -1)),
        ('MLP', MLPClassifier(random_state= 42)),
        ('CB', CatBoostClassifier(random_seed= 42, verbose= False))
    ], voting='soft')
    print(f"Model Trained \n({i})")
    
    ensemble.fit(X_train, y_train)
    print(f"Model Fitted \n({i})")
    
    title = y_string[8:]
    joblib.dump(ensemble, f"{title}.pkl")
    print(f"Model Dumped to .pkl File \n({i})")
    del X_train, y_string, y_train, ensemble, title

# %%
b = "y" + printing_list[2][1:]
print(b)
c = b[8:]
print(c)
# Out:
# y_train_FLT1_class
# FLT1_class

# %%
for i in printing_list:
    X_train = pd.read_csv(f"{i}.csv")
    print("X Import Successful")
    y_string = "y" + i[1:]

    y_train = pd.read_csv(f"{y_string}.csv")
    print("Y Import Successful")

# %%
X_train = pd.read_csv(f"X_train_EGFR_class.csv")
y_train = pd.read_csv(f"y_train_EGFR_class.csv")

# %%
y_train = pd.read_csv(f"y_train_EGFR_class.csv")
print(y_train.shape,
    X_train.shape)
# Out:
# (473719, 2) (473718, 2048)

# %%
y_train = y_train["Class"]
y_train.pop(473719)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMClassifier, LGBMRegressor
from xgboost import XGBClassifier, XGBRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC, SVR
from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.metrics import accuracy_score
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp
from sklearn.ensemble import VotingClassifier, VotingRegressor

from sklearn.linear_model import LogisticRegression

# %%
y_train.pop(len(y_train) - 1)
# Out:
# (473718, 2048) (473719,)
# np.int64(0)

# %%
ensemble = VotingClassifier(estimators=[
    ('LR', LogisticRegression(max_iter=1000, solver='saga')),
    ('RF', RandomForestClassifier(random_state= 42, n_jobs= -1)), 
    ('LGB', LGBMClassifier(random_state= 42, n_jobs= -1)),
    ('CB', CatBoostClassifier(random_seed= 42, verbose= False))
], voting='soft')
ensemble.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 3295, number of negative: 470423
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.429504 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4096
# [LightGBM] [Info] Number of data points in the train set: 473718, number of used features: 2048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.006956 -> initscore=-4.961226
# [LightGBM] [Info] Start training from score -4.961226
# VotingClassifier(estimators=[('LR',
#                               LogisticRegression(max_iter=1000, solver='saga')),
#                              ('RF',
#                               RandomForestClassifier(n_jobs=-1,
#                                                      random_state=42)),
#                              ('LGB',
#                               LGBMClassifier(n_jobs=-1, random_state=42)),
# ...

# %%
from sklearn.metrics import accuracy_score
X_test = pd.read_csv(f"X_test_EGFR_class.csv")
y_pred = ensemble.predict(X_test)
y_test = pd.read_csv(f"y_test_EGFR_class.csv")
accuracy = accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 from sklearn.metrics import accuracy_score
#       2 X_test = pd.read_csv(f"X_test_EGFR_class.csv")
# ----> 3 y_pred = ensemble.predict(X_test)
#       4 y_test = pd.read_csv(f"y_test_EGFR_class.csv")
#       5 accuracy = accuracy_score(y_test, y_pred)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:422, in VotingClassifier.predict(self, X)
#     420 check_is_fitted(self)
#     421 if self.voting == "soft":
# --> 422     maj = np.argmax(self.predict_proba(X), axis=1)
#     424 else:  # 'hard' voting
#     425     predictions = self._predict(X)
#
# File ~\anaconda3\envs\DCU\Lib\site-packages\sklearn\ensemble\_voting.py:463, in VotingClassifier.predict_proba(self, X)
#     449 """Compute probabilities of possible outcomes for samples in X.
#     450
#     451 Parameters
# ...

# %%
y_test = pd.read_csv(f"y_test_EGFR_class.csv")
X_test = pd.read_csv(f"X_test_EGFR_class.csv")

# Edits: Removed MLP and SVC - Just not possible with hardware available (SVC would use ~1.8 TB of RAM, MLP is too complex for the complexity of this data

# %%
y_test.pop(len(y_test) - 1)
print(y_test.shape, X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DCU\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 157906
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 y_test.pop(len(y_test) - 1)
# ...
